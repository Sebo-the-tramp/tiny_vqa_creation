# %%
import os
import ijson
import glob
import re 

def natural_key(s):
    return [int(t) if t.isdigit() else t.lower() for t in re.split(r'(\d+)', s)]

root_dir = ["/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random", "/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary"]

simulation_roots = root_dir
list_simulations = []

for simulation_root in simulation_roots:
    pattern = os.path.join(simulation_root, '**', 'simulation.json')    

    print("Searching for simulation files with pattern:", pattern)        
    for sim_file in glob.glob(pattern, recursive=True):
        list_simulations.append(sim_file)

list_simulations.sort(key=natural_key)

print(f"Found {len(list_simulations)} simulation files.")


# a fare bene dovrei controllare se nell'oggetto della domanda ci sono oggetti nella simulazione con lo stesso nome

simulation_cache = {}
total_duplicates = 0
for sim_file in list_simulations:
    with open(sim_file, 'r') as f:
        # print(f"Processing simulation file: {sim_file}")
        # iterate over each key-value pair in "objects"
        duplicated_names = {}
        for key, obj in ijson.kvitems(f, 'objects'):
            name = obj.get('model', {})
            if name:
                if name not in duplicated_names:
                    duplicated_names[name] = 1
                else:
                    duplicated_names[name] += 1

        # Store the duplicated names for this simulation
        simulation_cache[sim_file] = duplicated_names
        for name, count in duplicated_names.items():
            if count > 1:
                total_duplicates += 1
                print(f"Simulation file {sim_file} has multiple objects with the same name '{name}': {count} instances.")

print('number of simulations with duplicated object names:')
print(total_duplicates)
# Out:
# Searching for simulation files with pattern: /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/**/simulation.json
# Searching for simulation files with pattern: /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/**/simulation.json
# Found 1282 simulation files.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_115621/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_122827/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_124335/simulation.json has multiple objects with the same name 'LEGO_Fusion_Set_Town_Master': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-20_20251102_191052/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_193848/simulation.json has multiple objects with the same name 'Simon_Swipe_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_130847/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json has multiple objects with the same name 'LEGO_Fusion_Set_Town_Master': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_200106/simulation.json has multiple objects with the same name 'Poppin_File_Sorter_White': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_201910/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_202144/simulation.json has multiple objects with the same name 'BALANCING_CACTUS': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_202657/simulation.json has multiple objects with the same name 'Simon_Swipe_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_135800/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json has multiple objects with the same name 'LEGO_Fusion_Set_Town_Master': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_203719/simulation.json has multiple objects with the same name 'Hasbro_Trivial_Pursuit_Family_Edition_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_205442/simulation.json has multiple objects with the same name 'Poppin_File_Sorter_White': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_211511/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_211807/simulation.json has multiple objects with the same name 'BALANCING_CACTUS': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_212443/simulation.json has multiple objects with the same name 'Simon_Swipe_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_144118/simulation.json has multiple objects with the same name 'Whey_Protein_Vanilla': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_145656/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json has multiple objects with the same name 'Hasbro_Trivial_Pursuit_Family_Edition_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_215422/simulation.json has multiple objects with the same name 'Mens_ASV_Billfish_Boat_Shoe_in_Tan_Leather_wmUJ5PbwANc': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-37_20251102_220659/simulation.json has multiple objects with the same name 'Ortho_Forward_Facing': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_221344/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_221537/simulation.json has multiple objects with the same name 'BALANCING_CACTUS': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_222154/simulation.json has multiple objects with the same name 'Olive_Kids_Birdie_Lunch_Box': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-49_20251102_222703/simulation.json has multiple objects with the same name 'Nintendo_Yoshi_Action_Figure': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_154045/simulation.json has multiple objects with the same name 'Whey_Protein_Vanilla': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-96_20251103_163404/simulation.json has multiple objects with the same name 'Balderdash_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-97_20251103_163411/simulation.json has multiple objects with the same name 'Firefly_Clue_Board_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_005109/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_012317/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_013746/simulation.json has multiple objects with the same name 'LEGO_Fusion_Set_Town_Master': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-20_20251102_072305/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_074018/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_074928/simulation.json has multiple objects with the same name 'Simon_Swipe_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_020148/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_022010/simulation.json has multiple objects with the same name 'LEGO_Fusion_Set_Town_Master': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_081232/simulation.json has multiple objects with the same name 'Poppin_File_Sorter_White': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_082916/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_083258/simulation.json has multiple objects with the same name 'BALANCING_CACTUS': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_083732/simulation.json has multiple objects with the same name 'Simon_Swipe_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_025015/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json has multiple objects with the same name 'LEGO_Fusion_Set_Town_Master': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_084740/simulation.json has multiple objects with the same name 'Hasbro_Trivial_Pursuit_Family_Edition_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_090457/simulation.json has multiple objects with the same name 'Poppin_File_Sorter_White': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_092524/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_093047/simulation.json has multiple objects with the same name 'BALANCING_CACTUS': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_093659/simulation.json has multiple objects with the same name 'Simon_Swipe_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_033307/simulation.json has multiple objects with the same name 'Whey_Protein_Vanilla': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_034838/simulation.json has multiple objects with the same name 'JUNGLE_HEIGHT': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_094606/simulation.json has multiple objects with the same name 'Hasbro_Trivial_Pursuit_Family_Edition_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_100416/simulation.json has multiple objects with the same name 'Poppin_File_Sorter_White': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_100551/simulation.json has multiple objects with the same name 'Mens_ASV_Billfish_Boat_Shoe_in_Tan_Leather_wmUJ5PbwANc': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-37_20251102_102026/simulation.json has multiple objects with the same name 'Ortho_Forward_Facing': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_102245/simulation.json has multiple objects with the same name 'Imaginext_Castle_Ogre': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_102911/simulation.json has multiple objects with the same name 'BALANCING_CACTUS': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_103418/simulation.json has multiple objects with the same name 'Olive_Kids_Birdie_Lunch_Box': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-49_20251102_103849/simulation.json has multiple objects with the same name 'Nintendo_Yoshi_Action_Figure': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_043445/simulation.json has multiple objects with the same name 'Whey_Protein_Vanilla': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-96_20251103_052734/simulation.json has multiple objects with the same name 'Balderdash_Game': 2 instances.
# Simulation file /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-97_20251103_052801/simulation.json has multiple objects with the same name 'Firefly_Clue_Board_Game': 2 instances.
# number of simulations with duplicated object names:
# 63

# %%
print(simulation_cache)
# Out:
# {'/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-0_20251102_163324/simulation.json': {'Pepsi_Max_Cola_Zero_Calorie_12_12_fl_oz_355_ml_cans_144_fl_oz_426_lt': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-1_20251102_163634/simulation.json': {'Dino_3': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-2_20251102_163727/simulation.json': {'Schleich_Therizinosaurus_ln9cruulPqc': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-3_20251102_163747/simulation.json': {'Mens_ASV_Billfish_Boat_Shoe_in_Tan_Leather_wmUJ5PbwANc': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-4_20251102_163817/simulation.json': {'Rexy_Glove_Heavy_Duty_Large': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-5_20251102_163854/simulation.json': {'D_ROSE_45': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_163854/simulation.json': {'Lovable_Huggable_Cuddly_Boutique_Teddy_Bear_Beige': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-7_20251102_163914/simulation.json': {'Playmates_nickelodeon_teenage_mutant_ninja_turtles_shredder': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-8_20251102_163952/simulation.json': {'2_of_Jenga_Classic_Game': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-9_20251102_164018/simulation.json': {'Olive_Kids_Paisley_Pencil_Case': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-10_20251102_164041/simulation.json': {'Timberland_Mens_Earthkeepers_Stormbuck_Plain_Toe_Oxford': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-11_20251102_164121/simulation.json': {'Squirrel': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-12_20251102_164123/simulation.json': {'Marvel_Avengers_Titan_Hero_Series_Doctor_Doom': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-13_20251102_164148/simulation.json': {'Nintendo_Yoshi_Action_Figure': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-14_20251102_164226/simulation.json': {'Poppin_File_Sorter_White': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-15_20251102_164240/simulation.json': {'Hasbro_Monopoly_Hotels_Game': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-16_20251102_164305/simulation.json': {'Threshold_Porcelain_Spoon_Rest_White': 1}, '/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/1/c-1_no-1_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-17_20251102_164341/simulation.jso ...

# %%
import json
questions_path = "/data0/sebastian.cavada/compositional-physics/tiny_vqa_deterministic/output/run_08_general/test_run_08_general_10K.json"

with open(questions_path, 'r') as f:
    questions = json.load(f)

# %%
gso_mapping['JUNGLE_HEIGHT']
# Out:
# {'name': 'foldable activity scroll for baby'}

# %%
names = [gso_mapping[key]['name'] for key, value in simulation_cache["/data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-88_20251103_010246/simulation.json"].items()]
print(names)
# Out:
# ['boxed Trivial Pursuit board game', 'brown Timberland shoe']

# %%
count = 0
count_per_question_id = {}

for question in questions:
    simulation_id = question['simulation_id']
    if simulation_id in simulation_cache:
        # print(f"Checking simulation ID: {simulation_id}")

        # print(simulation_cache[simulation_id])

        names = [gso_mapping[key]['name'] for key, value in simulation_cache[simulation_id].items() if value > 1]
        if len(names) > 0:
            print(names)
            print(simulation_id)            

            for name in names:
                print(name)

                if name in question['question']:
                    print(f"Found matching name in question: {name}")
                    if question['question_id'] not in count_per_question_id:
                        count_per_question_id[question['question_id']] = 0
                    count_per_question_id[question['question_id']] += 1
                    count += 1
                    break

    else:
        print(f"Simulation ID {simulation_id} not found in simulation cache.")

print(f"Total count of matching names: {count}")
print("Percentage:", (count / len(questions)) * 100)
print("Count per question ID:", count_per_question_id)
print(len(count_per_question_id))
# Out:
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_090457/simulation.json
# light gray file organizer rack
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_124335/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_124335/simulation.json
# 256-piece LEGO Fusion boxed set
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_135800/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_025015/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_025015/simulation.json
# foldable activity scroll for baby
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_013746/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_013746/simulation.json
# 256-piece LEGO Fusion boxed set
# ['Simon-Swipe electronic memory game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_202657/simulation.json
# Simon-Swipe electronic memory game
# ['Simon-Swipe electronic memory game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_202657/simulation.json
# Simon-Swipe electronic memory game
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_033307/simulation.json
# white jar of proteins
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_034838/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_034838/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_094606/simulation.json
# boxed Trivial Pursuit board game
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_005109/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_005109/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_203719/simulation.json
# boxed Trivial Pursuit board game
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json
# 256-piece LEGO Fusion boxed set
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_020148/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_034838/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_034838/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_115621/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# ['boxed Balderdash board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-96_20251103_052734/simulation.json
# boxed Balderdash board game
# ['boxed Balderdash board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-96_20251103_052734/simulation.json
# boxed Balderdash board game
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_145656/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_145656/simulation.json
# foldable activity scroll for baby
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-20_20251102_072305/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-20_20251102_072305/simulation.json
# green ogre toy figurine
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_202144/simulation.json
# colored cactus balancing toy
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_202144/simulation.json
# colored cactus balancing toy
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# ['brown boat shoe']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_215422/simulation.json
# brown boat shoe
# ['brown boat shoe']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_215422/simulation.json
# brown boat shoe
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_074018/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_074018/simulation.json
# green ogre toy figurine
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_034838/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_034838/simulation.json
# foldable activity scroll for baby
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_124335/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_124335/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_020148/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_020148/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_081232/simulation.json
# light gray file organizer rack
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json
# 256-piece LEGO Fusion boxed set
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_082916/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_092524/simulation.json
# green ogre toy figurine
# ['yellow giraffe toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-37_20251102_102026/simulation.json
# yellow giraffe toy
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_074018/simulation.json
# green ogre toy figurine
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_222154/simulation.json
# turquoise insulated lunch bag
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_074018/simulation.json
# green ogre toy figurine
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_094606/simulation.json
# boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_094606/simulation.json
# boxed Trivial Pursuit board game
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_135800/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_135800/simulation.json
# foldable activity scroll for baby
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_102245/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_102245/simulation.json
# green ogre toy figurine
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_025015/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_025015/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_033307/simulation.json
# white jar of proteins
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_033307/simulation.json
# white jar of proteins
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_122827/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_122827/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_144118/simulation.json
# white jar of proteins
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_144118/simulation.json
# white jar of proteins
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_022010/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_022010/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_145656/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_145656/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_005109/simulation.json
# foldable activity scroll for baby
# ['brown boat shoe']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_100551/simulation.json
# brown boat shoe
# Found matching name in question: brown boat shoe
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_201910/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_201910/simulation.json
# green ogre toy figurine
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_013746/simulation.json
# 256-piece LEGO Fusion boxed set
# ['CLUE board game box']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-97_20251103_052801/simulation.json
# CLUE board game box
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_012317/simulation.json
# foldable activity scroll for baby
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_093047/simulation.json
# colored cactus balancing toy
# Found matching name in question: colored cactus balancing toy
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_124335/simulation.json
# 256-piece LEGO Fusion boxed set
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_005109/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_005109/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_222154/simulation.json
# turquoise insulated lunch bag
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_222154/simulation.json
# turquoise insulated lunch bag
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_222154/simulation.json
# turquoise insulated lunch bag
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_222154/simulation.json
# turquoise insulated lunch bag
# ['yellow giraffe toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-37_20251102_102026/simulation.json
# yellow giraffe toy
# ['yellow giraffe toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-37_20251102_102026/simulation.json
# yellow giraffe toy
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# ['brown boat shoe']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_100551/simulation.json
# brown boat shoe
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_211511/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_211511/simulation.json
# green ogre toy figurine
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_100416/simulation.json
# light gray file organizer rack
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_100416/simulation.json
# light gray file organizer rack
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_020148/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_020148/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_031339/simulation.json
# 256-piece LEGO Fusion boxed set
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_211511/simulation.json
# green ogre toy figurine
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_122827/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_020148/simulation.json
# foldable activity scroll for baby
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# Found matching name in question: green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_205442/simulation.json
# light gray file organizer rack
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_211807/simulation.json
# colored cactus balancing toy
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_211807/simulation.json
# colored cactus balancing toy
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_130847/simulation.json
# foldable activity scroll for baby
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_221344/simulation.json
# green ogre toy figurine
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_202144/simulation.json
# colored cactus balancing toy
# Found matching name in question: colored cactus balancing toy
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_033307/simulation.json
# white jar of proteins
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# Found matching name in question: green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# Found matching name in question: green ogre toy figurine
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_084740/simulation.json
# boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_084740/simulation.json
# boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_094606/simulation.json
# boxed Trivial Pursuit board game
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_130847/simulation.json
# foldable activity scroll for baby
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_103418/simulation.json
# turquoise insulated lunch bag
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_103418/simulation.json
# turquoise insulated lunch bag
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# Found matching name in question: boxed Trivial Pursuit board game
# ['brown boat shoe']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_100551/simulation.json
# brown boat shoe
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['brown boat shoe']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_215422/simulation.json
# brown boat shoe
# Found matching name in question: brown boat shoe
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_074018/simulation.json
# green ogre toy figurine
# Found matching name in question: green ogre toy figurine
# ['Simon-Swipe electronic memory game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_212443/simulation.json
# Simon-Swipe electronic memory game
# ['Simon-Swipe electronic memory game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_212443/simulation.json
# Simon-Swipe electronic memory game
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_122827/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_135800/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_135800/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_130847/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_130847/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_122827/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_122827/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# Found matching name in question: boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# Found matching name in question: boxed Trivial Pursuit board game
# ['Yoshi figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-49_20251102_103849/simulation.json
# Yoshi figurine
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_013746/simulation.json
# 256-piece LEGO Fusion boxed set
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# ['brown boat shoe']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_215422/simulation.json
# brown boat shoe
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_012317/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_145656/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_145656/simulation.json
# foldable activity scroll for baby
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_013746/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_074018/simulation.json
# green ogre toy figurine
# ['CLUE board game box']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-97_20251103_163411/simulation.json
# CLUE board game box
# Found matching name in question: CLUE board game box
# ['brown boat shoe']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_215422/simulation.json
# brown boat shoe
# Found matching name in question: brown boat shoe
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_034838/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_130847/simulation.json
# foldable activity scroll for baby
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_200106/simulation.json
# light gray file organizer rack
# ['brown boat shoe']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-25_20251102_100551/simulation.json
# brown boat shoe
# Found matching name in question: brown boat shoe
# ['Yoshi figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-49_20251102_222703/simulation.json
# Yoshi figurine
# ['Yoshi figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-49_20251102_222703/simulation.json
# Yoshi figurine
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_130847/simulation.json
# foldable activity scroll for baby
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_094606/simulation.json
# boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_094606/simulation.json
# boxed Trivial Pursuit board game
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_012317/simulation.json
# foldable activity scroll for baby
# ['CLUE board game box']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-97_20251103_052801/simulation.json
# CLUE board game box
# Found matching name in question: CLUE board game box
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_202144/simulation.json
# colored cactus balancing toy
# Found matching name in question: colored cactus balancing toy
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_145656/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_145656/simulation.json
# foldable activity scroll for baby
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_093047/simulation.json
# colored cactus balancing toy
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_043445/simulation.json
# white jar of proteins
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_043445/simulation.json
# white jar of proteins
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_200106/simulation.json
# light gray file organizer rack
# ...
# foldable activity scroll for baby
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_135800/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_135800/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_221344/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_221344/simulation.json
# green ogre toy figurine
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_012317/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_012317/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_093047/simulation.json
# colored cactus balancing toy
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_043445/simulation.json
# white jar of proteins
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_033307/simulation.json
# white jar of proteins
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_033307/simulation.json
# white jar of proteins
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_205442/simulation.json
# light gray file organizer rack
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json
# 256-piece LEGO Fusion boxed set
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_102911/simulation.json
# colored cactus balancing toy
# ['Yoshi figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-49_20251102_103849/simulation.json
# Yoshi figurine
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_222154/simulation.json
# turquoise insulated lunch bag
# Found matching name in question: turquoise insulated lunch bag
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_222154/simulation.json
# turquoise insulated lunch bag
# Found matching name in question: turquoise insulated lunch bag
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_130847/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_012317/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_020148/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_020148/simulation.json
# foldable activity scroll for baby
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_154045/simulation.json
# white jar of proteins
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_154045/simulation.json
# white jar of proteins
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_100416/simulation.json
# light gray file organizer rack
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_100416/simulation.json
# light gray file organizer rack
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_205442/simulation.json
# light gray file organizer rack
# ['light gray file organizer rack']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-22_20251102_205442/simulation.json
# light gray file organizer rack
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_013746/simulation.json
# 256-piece LEGO Fusion boxed set
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_213404/simulation.json
# boxed Trivial Pursuit board game
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_074018/simulation.json
# green ogre toy figurine
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_043445/simulation.json
# white jar of proteins
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_033307/simulation.json
# white jar of proteins
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_033307/simulation.json
# white jar of proteins
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# Found matching name in question: green ogre toy figurine
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_022010/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['Yoshi figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-49_20251102_103849/simulation.json
# Yoshi figurine
# ['Yoshi figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-49_20251102_103849/simulation.json
# Yoshi figurine
# ['turquoise insulated lunch bag']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-47_20251102_103418/simulation.json
# turquoise insulated lunch bag
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_142312/simulation.json
# 256-piece LEGO Fusion boxed set
# Found matching name in question: 256-piece LEGO Fusion boxed set
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_092524/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_092524/simulation.json
# green ogre toy figurine
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_034838/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_122827/simulation.json
# foldable activity scroll for baby
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_094606/simulation.json
# boxed Trivial Pursuit board game
# ['boxed Trivial Pursuit board game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-6_20251102_094606/simulation.json
# boxed Trivial Pursuit board game
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['green ogre toy figurine']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-39_20251102_192831/simulation.json
# green ogre toy figurine
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_083258/simulation.json
# colored cactus balancing toy
# ['colored cactus balancing toy']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-43_20251102_083258/simulation.json
# colored cactus balancing toy
# ['white jar of proteins']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-58_20251103_144118/simulation.json
# white jar of proteins
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/3/c-1_no-3_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_124335/simulation.json
# 256-piece LEGO Fusion boxed set
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_135800/simulation.json
# foldable activity scroll for baby
# ['CLUE board game box']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-97_20251103_052801/simulation.json
# CLUE board game box
# ['CLUE board game box']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/7/c-1_no-7_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-97_20251103_052801/simulation.json
# CLUE board game box
# ['Simon-Swipe electronic memory game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_212443/simulation.json
# Simon-Swipe electronic memory game
# ['Simon-Swipe electronic memory game']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/6/c-1_no-6_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-48_20251102_212443/simulation.json
# Simon-Swipe electronic memory game
# ['256-piece LEGO Fusion boxed set']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random-cam-stationary/4/c-1_no-4_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-91_20251103_132815/simulation.json
# 256-piece LEGO Fusion boxed set
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_025015/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/5/c-1_no-5_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_025015/simulation.json
# foldable activity scroll for baby
# ['foldable activity scroll for baby']
# /data0/sebastian.cavada/datasets/simulations_v3/dl3dv/random/2/c-1_no-2_d-4_s-dl3dv-all_models-hf-gso_MLP-10_smooth_h-10-40_seed-71_20251103_005109/simulation.json
# foldable activity scroll for baby
# Found matching name in question: foldable activity scroll for baby
# Total count of matching names: 78
# Percentage: 0.7799999999999999
# Count per question ID: {'F_MASS_HEAVIEST_OBJECT': 16, 'F_SIZE_OBJECT_BIGGER': 8, 'F_COLLISION_OBJECT_SCENE_FRAME_MULTI': 5, 'F_CLOSEST_OBJECT_OBJECT': 6, 'F_COLLISIONS_OBJ_OBJ_FIRST': 8, 'F_VISIBILITY_PERCENTAGE_OBJECT': 4, 'F_COLLISION_OBJECT_OBJECT_FRAME_SINGLE': 15, 'F_MATERIAL_IDENTIFICATION_OBJECT': 4, 'F_PHYSICS_PROPERTY_YOUNG_MODULUS_OBJECT': 2, 'F_PHYSICS_PROPERTY_DENSITY_OBJECT': 4, 'F_CLOSEST_OBJECT_CAMERA': 4, 'F_LAYOUT_POSITION_OBJECT_OBJECT': 2}
# 12

# %%
# thus the the check for duplicate objects might not be working  as intended
print(len(questions))
# Out:
# 10000
