# %%
import json

def read_simulation(simulation_path):
    with open(simulation_path, "r") as f:
        simulation_steps = json.load(f)
    return simulation_steps

# %%
data = read_simulation("/data0/sebastian.cavada/datasets/simulations_v4/dl3dv-counterfact/rescale/random/1/c-1_no-1_cl-output-sims-v4-dl3dv-random-1-all_seed-0_all_d-10_s-data-3dgrt-tools_revised2.ply_models-default_seed-0_20260119_002240/simulation.json")

# %%
data['objects']['1']
# Out:
# {'model': 'My_Monopoly_Board_Game',
#  'sim': 'rho-medium_yms-stiffer_prs-medium',
#  'props': {'yms': 1500000000,
#   'prs': 0.3,
#   'rhos': 185,
#   'appx_vol': 0.007685305,
#   'name': 'rho-medium_yms-stiffer_prs-medium'},
#  'volume': 4987537.5,
#  'mass': 922694464.0,
#  'description': {'object_name': 'boxed My Monopoly board game',
# ...
